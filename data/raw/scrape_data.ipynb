# %% [markdown]
# #### Writing functions to scrape the following:
#     - match stats for every game in the "24/25" and "25/26" season
#     - season dictionary which will give us additional data to supplement final dataframe
#     - clean the data, replace NaN with zero's
#     - add extra columns and features
#     - handle columns that scrape was impossible for or error occured
#     - scrape momentum df, reshape the momentum dataframe, calculate the PCA, apply a sigmoid function to scale results to -10 and plus 10, and the add home_momentum and away_momentum to the season dataframe.
#     - scrape league table for the season and add some additional features to the table to customize it a bit.
#     - scrape shot data for every shot in every match, we will use this to compute more features for the season match dataframe

# %%
import pandas as pd
import ScraperFC as sfc
import numpy as np

# %%
match_shots = sfc.Sofascore().scrape_match_shots(12436410)
match_shots
# Out:
# Running
#                                                player  isHome shotType  \
# 0   {'name': 'Yoane Wissa', 'slug': 'yoane-wissa',...    True     miss
# 1   {'name': 'Gabriel Jesus', 'slug': 'gabriel-jes...   False     miss
# 2   {'name': 'Mikel Merino', 'slug': 'mikel-merino...   False     miss
# 3   {'name': 'Gabriel Martinelli', 'slug': 'gabrie...   False     goal
# 4   {'name': 'Mikel Merino', 'slug': 'mikel-merino...   False     goal
# 5   {'name': 'Gabriel Jesus', 'slug': 'gabriel-jes...   False     save
# 6   {'name': 'Gabriel Martinelli', 'slug': 'gabrie...   False    block
# 7   {'name': 'Thomas Partey', 'firstName': '', 'la...   False    block
# 8   {'name': 'Yoane Wissa', 'slug': 'yoane-wissa',...    True     miss
# 9   {'name': 'Gabriel Jesus', 'slug': 'gabriel-jes...   False     goal
# 10  {'name': 'Thomas Partey', 'firstName': '', 'la...   False     save
# 11  {'name': 'Gabriel Martinelli', 'slug': 'gabrie...   False    block
# ...

# %%
team_league_stats = sfc.Sofascore().scrape_team_league_stats('24/25', 'England Premier League')
# Out:
# 24/25 England Premier League team stats: 100%|██████████████████████| 20/20 [00:55<00:00,  2.77s/it]

# %%
team_league_stats
# Out:
# Index(['teamName', 'teamId', 'goalsScored', 'goalsConceded', 'ownGoals',
#        'assists', 'shots', 'penaltyGoals', 'penaltiesTaken', 'freeKickGoals',
#        ...
#        'totalPassesAgainst', 'yellowCardsAgainst', 'throwIns', 'goalKicks',
#        'ballRecovery', 'freeKicks', 'id', 'matches', 'awardedMatches',
#        'statisticsType'],
#       dtype='object', length=117)

# %%
fbref_league_table = sfc.FBref().scrape_league_table('24/25', 'England Premier League')
fbref_league_table
# Out:
# Task failed for input: https://fbref.com/en/comps/9/history/Premier-League-Seasons
# Traceback (most recent call last):
#   File "C:\Users\enaic\AppData\Roaming\Python\Python314\site-packages\botasaurus\browser_decorator.py", line 201, in run_task
#     result = func(driver, data)
#   File "C:\Users\enaic\AppData\Roaming\Python\Python314\site-packages\ScraperFC\fbref.py", line 53, in _
#     driver.wait_for_element("body.fb", wait=10)
#     ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\enaic\AppData\Roaming\Python\Python314\site-packages\botasaurus_driver\driver.py", line 1246, in wait_for_element
#     return self._make_element(self._tab.wait_for(selector, timeout=wait))
#                               ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\enaic\AppData\Roaming\Python\Python314\site-packages\botasaurus_driver\core\tab.py", line 1314, in wait_for
#     item = self.query_selector(selector)
# ...

# %%
match_shots.to_csv('match_shots.csv', index=False)
